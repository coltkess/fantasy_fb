# %% [markdown]
# <h1>Scraping NFL Salary Data from Spotrac</h1>
#
# <p>Before I even get into anything here, I have a request: if you know where to find historical NFL salary data please let me know. Over the Cap and Spotrac both have salary histories for every <i>active</i> player, but I was hoping to go all the way back to 2000. I can't find a comprehensive dataset anywhere. </p>
#
# <p>On to the project. I already pulled all the fantasy stats from Sports Reference, now I need to scrape as much year-by-year, player-by-player salary data as I can, then merge the two datasets to look for interesting patterns.</p>
#
# <p>One of the great things about Python is that no matter what your idea, somebody somewhere has done at least part of the work for you and posted it on the internet. This was the case for me here.</p>
#
# <p>I Googled "scraping spotrac with python" and found <a href="https://wcontractor.github.io/nfl-salary-part2.html">this page by Wahid Contractor</a> about almost exactly that. I didn't end up using a majority of his methods, but I definitely used the team urls he scraped as a jumping-off point.</p>
#
# <p>I copied the team urls and pasted them into a text file called "spotrac_urls.txt", then got to work. (Yes, I could have just assigned them to a list, but I'm pretty new at this. I still need to practice everything I can.)</p>

# %%
import bs4 as bs
import urllib.request
import pandas as pd
import os

base_path = "/Users/coltkess/PycharmProjects/" #####
filename = "spotrac_urls.txt"
path_to_file = os.path.join(base_path, filename)


team_codes = []

with open(path_to_file , "r+") as f:
    for line in f:
        team_codes.append(line[28:-6])

team_codes
# Out:
# ['arizona-cardinals',
#  'atlanta-falcons',
#  'baltimore-ravens',
#  'buffalo-bills',
#  'carolina-panthers',
#  'chicago-bears',
#  'cincinnati-bengals',
#  'cleveland-browns',
#  'dallas-cowboys',
#  'denver-broncos',
#  'detroit-lions',
#  'green-bay-packers',
#  'houston-texans',
#  'indianapolis-colts',
#  'jacksonville-jaguars',
#  'kansas-city-chiefs',
#  'los-angeles-chargers',
#  'los-angeles-rams',
#  'miami-dolphins',
#  'minnesota-vikings',
#  'new-england-patriots',
#  'new-orleans-saints',
#  'new-york-giants',
#  'new-york-jets',
#  'oakland-raiders',
#  'philadelphia-eagles',
#  'pittsburgh-steelers',
#  'san-francisco-49ers',
#  'seattle-seahawks',
#  'tampa-bay-buccaneers',
#  'tennessee-titans',
#  'washington-redskins']

# %% [markdown]
# <p>Now I have the piece of the url that differentiates one team from the next, which is a good start. I can iterate through these, adding each one to Spotrac's url structure to scrape the urls of each player page from each roster. </p>
#
# <p>The url I need to add the `team_codes` to is https://www.spotrac.com/nfl/{team_code}/cap/.</p>
#
# <p>I started by creating an empty dictionary called `teams_dict`, which will structure data like this:</p>
#
# `teams_dict = {team-code: {'Player Name': 'player-code-####'}}`
#
# <p>Spotrac adds a unique number to each player's name in their url differentiate one Marcus Smith from the other. </p>
#
# <p>Marcus Smith, WR, Baltimore: https://www.spotrac.com/nfl/baltimore-ravens/marcus-smith-4002/</p>
# <p>Marcus Smith, DE, Buffalo: https://www.spotrac.com/nfl/buffalo-bills/marcus-smith-5638/</p>
# <p>Marcus Smith, DE, Seattle: https://www.spotrac.com/nfl/seattle-seahawks/marcus-smith-14435/</p>
#
# <p>As far as I can tell, the logic of the numbers is based on when the player came into the league, but that's just a guess. It's easier to scrape each player's code than it is to figure out the logic behind the numbering system.</p>
#
# <p>That's what I need to isolate with 'player-code-####'.</p>

# %%
teams_dict = {}

# First I'll define a function which takes a team code as its only argument, then scrapes the player url of
# every player on the team's 53-man roster and adds all of it to the teams_dict.

def get_player_ids(team):
    # I create my beautifulsoup, then isolate the 53-man roster.
    byte_byte = urllib.request.urlopen("https://www.spotrac.com/nfl/{team}/cap/".format(team=team))
    soups = bs.BeautifulSoup(byte_byte, 'lxml')
    table = soups.find("table", class_="datatable")
    tablesoup = bs.BeautifulSoup(str(table), 'lxml')

    # Here I grab the player name from the soup, then grab the link associated with that name as well.
    keys = [link.get_text() for link in tablesoup.find_all("a", href=True)]
    vls = [link["href"] for link in tablesoup.find_all("a", href=True)]

    # I used the cleveland-browns team code to check the two lists were the same length 
    # (both 53 items) and they weren't, so I had to remove some junk to pare my list down to just the player
    # names and the urls for each player. 
    
    player_keys = []
    link_values = []
    
    for k in keys:
        if '(' not in k:
            player_keys.append(k)
    
    # ONE item on the Philadelphia Eagles roster table had a value of '-'. So this line of code removes that ONE item.
    if '-' in player_keys:
        player_keys.remove('-')
    
    # Every other value in vls is just "#", so those have to go.
    for v in vls:
        if v != '#':
            link_values.append(v)
    
    # The links pulled from the table are formatted like this: 'https://www.spotrac.com/redirect/player/7899/'
    # and I don't want my crawler to have to go through the redirect every time it tries to get to a player page. 
    # Lucky for me, the number at the end is the #### part of the 'player-code-####' I need. So I isolated those
    # values in the following list:
    splt_vls = [l.rsplit('/')[-2] for l in link_values]

    # Lots of NFL players have apostrophes in their names, but apostrophes don't work in
    # urls, so the apostrophes have to go. This also adds the dash between first/last names so I can combine
    # these values with my splt_vls above and hopefully get my 'player-code-####'.
    players = [v.replace(' ', '-').replace("'", "").lower() for v in player_keys]

    # This creates a blank dictionary for player urls.
    player_ids_dict = {}

    # spotrac_player_id is the list of 'player-code-####' I said I needed at the beginning. 
    spotrac_player_id = ["{}-{}".format(players[i], splt_vls[i]) for i in range(len(player_keys))]
    
    # Now I take each of the player names I grabbed and added to my player_keys list and use them as keys
    # for dictionaries called 'player_ids_dict', which sets up like this: 
    # player_ids_dict = {'Player One': 'player-code-1', 'Player Two': 'player-code-2'}
    for i in range(len(player_keys)):
        player_ids_dict[player_keys[i]] = spotrac_player_id[i]

    # Finally, I take the player_ids_dict created for the 'team' argument, check to make sure the 'team'
    # isn't in my 'teams_dict' and add the whole team to the dictionary like so:
    # teams_dict = {'new-york-giants': {'Eli Manning': 'eli-manning-4348', 'Olivier Vernon': 'olivier-vernon-9882', 'Janoris Jenkins': 'janoris-jenkins-9849'}}
    if team not in teams_dict:
        teams_dict[team] = player_ids_dict
        
    # This function doesn't actually return anything. Its purpose is purely to add to the teams_dict

# %% [markdown]
# Let's give it a try with the New York Giants, team_code: `new-york-giants`:

# %%
get_player_ids('new-york-giants')

teams_dict
# Out:
# {'new-york-giants': {'Eli Manning': 'eli-manning-4348',
#   'Olivier Vernon': 'olivier-vernon-9882',
#   'Janoris Jenkins': 'janoris-jenkins-9849',
#   'Nate Solder': 'nate-solder-7732',
#   'Damon Harrison': 'damon-harrison-10400',
#   'Saquon Barkley': 'saquon-barkley-25097',
#   'Odell Beckham, Jr.': 'odell-beckham,-jr.-14421',
#   'Alec Ogletree': 'alec-ogletree-12310',
#   'Ereck Flowers': 'ereck-flowers-16733',
#   'Eli Apple': 'eli-apple-18958',
#   'Jonathan Stewart': 'jonathan-stewart-4042',
#   'Rhett Ellison': 'rhett-ellison-9947',
#   'Kareem Martin': 'kareem-martin-14494',
#   'Cody Latimer': 'cody-latimer-14466',
#   'Patrick Omameh': 'patrick-omameh-12961',
#   'Evan Engram': 'evan-engram-21764',
#   'Michael Thomas': 'michael-thomas-10443',
#   'Landon Collins': 'landon-collins-16757',
#   'Connor Barwin': 'connor-barwin-5680',
#   'Sterling Shepard': 'sterling-shepard-18989',
#   'Will Hernandez': 'will-hernandez-25133',
#   'Mario Edwards': 'mario-edwards-16759',
# ...

# %% [markdown]
# Sweet. Now let's add the rest of our teams.

# %%
errors_list = []

for team in team_codes:
    try:
        get_player_ids(team)
    except Exception as e:
        # see reference_scraper.py line 148-152
        error = [team, e]
        errors_list.append(error)

teams_dict
# Out:
# {'new-york-giants': {'Eli Manning': 'eli-manning-4348',
#   'Olivier Vernon': 'olivier-vernon-9882',
#   'Janoris Jenkins': 'janoris-jenkins-9849',
#   'Nate Solder': 'nate-solder-7732',
#   'Damon Harrison': 'damon-harrison-10400',
#   'Saquon Barkley': 'saquon-barkley-25097',
#   'Odell Beckham, Jr.': 'odell-beckham,-jr.-14421',
#   'Alec Ogletree': 'alec-ogletree-12310',
#   'Ereck Flowers': 'ereck-flowers-16733',
#   'Eli Apple': 'eli-apple-18958',
#   'Jonathan Stewart': 'jonathan-stewart-4042',
#   'Rhett Ellison': 'rhett-ellison-9947',
#   'Kareem Martin': 'kareem-martin-14494',
#   'Cody Latimer': 'cody-latimer-14466',
#   'Patrick Omameh': 'patrick-omameh-12961',
#   'Evan Engram': 'evan-engram-21764',
#   'Michael Thomas': 'michael-thomas-10443',
#   'Landon Collins': 'landon-collins-16757',
#   'Connor Barwin': 'connor-barwin-5680',
#   'Sterling Shepard': 'sterling-shepard-18989',
#   'Will Hernandez': 'will-hernandez-25133',
#   'Mario Edwards': 'mario-edwards-16759',
# ...

# %% [markdown]
# Excellent. Let's make sure we have 53 players from all 32 rosters before we move on. Wouldn't want to miss anybody.

# %%
errors_list
# Out:
# []

# %%
checking_rosters = {}

for team in team_codes:
    checking_rosters[team] = {len(teams_dict[team].keys()):len(teams_dict[team].values())}
    
checking_rosters
# Out:
# {'arizona-cardinals': {53: 53},
#  'atlanta-falcons': {53: 53},
#  'baltimore-ravens': {53: 53},
#  'buffalo-bills': {52: 52},
#  'carolina-panthers': {53: 53},
#  'chicago-bears': {53: 53},
#  'cincinnati-bengals': {53: 53},
#  'cleveland-browns': {53: 53},
#  'dallas-cowboys': {54: 54},
#  'denver-broncos': {53: 53},
#  'detroit-lions': {53: 53},
#  'green-bay-packers': {53: 53},
#  'houston-texans': {54: 54},
#  'indianapolis-colts': {53: 53},
#  'jacksonville-jaguars': {53: 53},
#  'kansas-city-chiefs': {53: 53},
#  'los-angeles-chargers': {53: 53},
#  'los-angeles-rams': {53: 53},
#  'miami-dolphins': {53: 53},
#  'minnesota-vikings': {53: 53},
#  'new-england-patriots': {53: 53},
#  'new-orleans-saints': {53: 53},
#  'new-york-giants': {53: 53},
#  'new-york-jets': {53: 53},
#  'oakland-raiders': {56: 56},
#  'philadelphia-eagles': {54: 54},
#  'pittsburgh-steelers': {53: 53},
#  'san-francisco-49ers': {52: 52},
#  'seattle-seahawks': {53: 53},
# ...

# %% [markdown]
# Okay, so a few teams have 54, a few have 52, but we've got our team-names, our player-names, and our player-codes-####.
#
# Now it's time to get our data.

# %%
# I could have figured out a fancy way to get the columns, but sometimes it's faster to just 
# type out ten items than it is to parse through html.
column_headers = ['Year', 'Team', 'Salary', 'Signing_Bonus', 'Roster_Bonus', 'Workout_Bonus',
                  'Restructure_Bonus', 'Option_Bonus', 'Incentive', 'Total_Cash']

# This function is used in the function below to divide the salary data into even segments to 
# correspond to the columns above.
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# These are the lists we need to fill to make this work. Well, the first one at least. 
# After a few runs where it would get part-way through before the code errored out, 
# I decided to use the try/except syntax and add any errors to a list to address later.

all_players_salaries_dfs_list = []
player_errors = []

# This is url the structure of the pages with the data we want.
spotrac_url = "https://www.spotrac.com/nfl/{A}/{B}/cash-earnings/"

# Here we go. Run this at your own peril -- it takes about 15 minutes. It by iterating through the top level of the
# key:value pairs in team_dict, which means it takes team_name and {'Player Name': 'player-code-#####', 
# 'Player Two': 'player-two-#####', etc}, then iterates through the key:value pairs in the player_dict provided 
# in the first for loop as 'Player Name': 'player-code-####', 'Player Two': 'player-two-#####', etc, and runs them through
# the try: code. 
for team_name, player_dict in teams_dict.items():
    for player_name, player_id in player_dict.items():
        try:
            player_byte = urllib.request.urlopen(spotrac_url.format(A=team_name, B=player_id))
            soup = bs.BeautifulSoup(player_byte, 'lxml')
            table = soup.find("table", class_="earningstable")
            table_soup = bs.BeautifulSoup(str(table), 'lxml')

            for row in table_soup:  # For each row, do the following:
                # 1. Get the text for each table data "td" element (basically, every cell) in the row
                player_list = [td.get_text() for td in row.find_all("td")]

                player_salary_history = []
                
                # 2. Add the text from each "td" element to the player_salary_history table, and stop when you
                #    get to the word 'season', because that means you've reached the current total. Then remove the
                #    final value from the list, since we know the final value is 'season'.
                for i in player_list:
                    player_salary_history.append(i)
                    if "season" in i:
                        break
                player_salary_history.pop()
                
                # player_salary_history is one long list with ten items for each season the player has been employed,
                # so the 'player_chunks' function defined above breaks that long list into lists of 10 values each, 
                # one for each of our column headers.
                player_chunks = list(chunks(player_salary_history, 10))

            # This part was tricky. These lines take the image urls of the team logos in each line of the player_salary_history
            # table. Khalil Mack's current url is 'https://www.spotrac.com/nfl/chicago-bears/khalil-mack-14414/cash-earnings/'
            # but there are four very short-sighted Raiders logos on his table, and only one very lucky Chicago Bears C. So 
            # this code grabs the image name, isolates the team name section, and creates a list called 'teams'.
            teams_lst = table_soup.find_all("img", src=True)
            slices = [str(i).rsplit("/", 3)[-2] for i in teams_lst]
            teams = [i.rsplit(".")[-2] for i in slices]

            # Then we replace the empty string in index 1 with the team image name from the last section.
            for i in range(len(player_chunks)):
                player_chunks[i][1] = teams[i]
            
            # Creating the dataframe
            player_df = pd.DataFrame(player_chunks, columns=column_headers)

            # Inserting the "Player_Name" and "Spotrac_ID" columns to the dataframe for each player.
            player_df.insert(0, "Player_Name", player_name)
            player_df.insert(1, "Spotrac_ID", player_id)
            
            # Adding the dataframe values for each player to a list so we can create a massive dataframe at the end.
            # This section at least keeps things interesting results are compiled. It prints the first line of each 
            # player's salary history table is that player is added to the list. 
            player_df_list = player_df.values.tolist()
            print(player_df_list[0])
            all_players_salaries_dfs_list.append(player_df)
            
        except Exception as e:
            player_errors = [player_name, e]
            print("ERROR!!! {} is messed up.".format(player_name))
            errors_list.extend(player_errors)

salaries_df = pd.concat(all_players_salaries_dfs_list, ignore_index=True)

errors_list
# Out:
# ['Eli Manning', 'eli-manning-4348', '2004', 'nygiants', '$1,744,000', '$3,000,000', '-', '-', '-', '-', '-', '$4,744,000']
# ['Olivier Vernon', 'olivier-vernon-9882', '2012', 'dolphins', '$390,000', '$638,080', '-', '-', '-', '-', '-', '$1,028,080']
# ['Janoris Jenkins', 'janoris-jenkins-9849', '2012', 'rams2', '$390,000', '$2,069,324', '-', '-', '-', '-', '-', '$2,459,324']
# ['Nate Solder', 'nate-solder-7732', '2011', 'patriots', '$375,000', '$4,711,268', '-', '-', '-', '-', '-', '$5,086,268']
# ['Damon Harrison', 'damon-harrison-10400', '2012', 'jets', '$390,000', '$7,000', '-', '-', '-', '-', '-', '$397,000']
# ['Saquon Barkley', 'saquon-barkley-25097', '2018', 'nygiants', '$480,000', '$20,767,092', '-', '-', '-', '-', '-', '$21,247,092']
# ERROR!!! Odell Beckham, Jr. is messed up.
# ['Alec Ogletree', 'alec-ogletree-12310', '2013', 'rams2', '$405,000', '$3,492,752', '-', '-', '-', '-', '-', '$3,897,752']
# ...

# %%
odell = [['Odell Beckham Jr.', 'odell-beckham-jr-14421', '2014', 'nygiants', '$420,000', '$5,888,144','-','-','-','-','-','$6,308,144'],
['Odell Beckham Jr.', 'odell-beckham-jr-14421', '2015', 'nygiants','$840,479','-','-','-','-','-','$55,751','$896,230'],
['Odell Beckham Jr.', 'odell-beckham-jr-14421', '2016', 'nygiants','$1,366,018','-','-','-','-','-','-','$1,366,018'],
['Odell Beckham Jr.', 'odell-beckham-jr-14421', '2017', 'nygiants','$1,839,027','-','-','-','-','-','-','$1,839,027'],
['Odell Beckham Jr.', 'odell-beckham-jr-14421', '2018', 'nygiants','$1,459,000','$20,000,000','-','-','-','-','-','$21,459,000']]
    
sample_headers = ['Player_Name', 'Spotrac_ID','Year', 'Team', 'Salary', 'Signing_Bonus', 'Roster_Bonus', 'Workout_Bonus',
                  'Restructure_Bonus', 'Option_Bonus', 'Incentive', 'Total_Cash']

odell_df = pd.DataFrame(odell, columns=sample_headers)

complete_salaries_df = salaries_df.append(odell_df, ignore_index=True)

complete_salaries_df.tail(10)
# Out:
#               Player_Name                 Spotrac_ID  Year        Team  \
# 8665  Shaun-Dion Hamilton  shaun-dion-hamilton-25298  2018  washington
# 8666         Greg Stroman         greg-stroman-25342  2018  washington
# 8667           Trey Quinn           trey-quinn-25357  2018  washington
# 8668           Casey Dunn           casey-dunn-25927  2018  washington
# 8669        Danny Johnson        danny-johnson-25633  2018  washington
# 8670    Odell Beckham Jr.     odell-beckham-jr-14421  2014    nygiants
# 8671    Odell Beckham Jr.     odell-beckham-jr-14421  2015    nygiants
# 8672    Odell Beckham Jr.     odell-beckham-jr-14421  2016    nygiants
# 8673    Odell Beckham Jr.     odell-beckham-jr-14421  2017    nygiants
# 8674    Odell Beckham Jr.     odell-beckham-jr-14421  2018    nygiants
#
#           Salary Signing_Bonus Roster_Bonus Workout_Bonus Restructure_Bonus  \
# 8665    $480,000      $153,010            -             -                 -
# ...

# %%
complete_salaries_df.Total_Cash = complete_salaries_df.Total_Cash.str.replace('$', '')
complete_salaries_df.Total_Cash = complete_salaries_df.Total_Cash.str.replace(',', '')

complete_salaries_df.Total_Cash = complete_salaries_df.Total_Cash.str.replace('$', '')
complete_salaries_df.Total_Cash = complete_salaries_df.Total_Cash.str.replace(',', '')

complete_salaries_df.Salary = complete_salaries_df.Salary.str.replace('$', '')
complete_salaries_df.Salary = complete_salaries_df.Salary.str.replace(',', '')
complete_salaries_df.Salary = complete_salaries_df.Salary.str.replace('-', '')

complete_salaries_df.Signing_Bonus = complete_salaries_df.Signing_Bonus.str.replace('$', '')
complete_salaries_df.Signing_Bonus = complete_salaries_df.Signing_Bonus.str.replace(',', '')
complete_salaries_df.Signing_Bonus = complete_salaries_df.Signing_Bonus.str.replace('-', '')

complete_salaries_df.Roster_Bonus = complete_salaries_df.Roster_Bonus.str.replace('$', '')
complete_salaries_df.Roster_Bonus = complete_salaries_df.Roster_Bonus.str.replace(',', '')
complete_salaries_df.Roster_Bonus = complete_salaries_df.Roster_Bonus.str.replace('-', '')

complete_salaries_df.Workout_Bonus = complete_salaries_df.Workout_Bonus.str.replace('$', '')
complete_salaries_df.Workout_Bonus = complete_salaries_df.Workout_Bonus.str.replace(',', '')
complete_salaries_df.Workout_Bonus = complete_salaries_df.Workout_Bonus.str.replace('-', '')

complete_salaries_df.Restructure_Bonus = complete_salaries_df.Restructure_Bonus.str.replace('$', '')
complete_salaries_df.Restructure_Bonus = complete_salaries_df.Restructure_Bonus.str.replace(',', '')
complete_salaries_df.Restructure_Bonus = complete_salaries_df.Restructure_Bonus.str.replace('-', '')

complete_salaries_df.Option_Bonus = complete_salaries_df.Option_Bonus.str.replace('$', '')
complete_salaries_df.Option_Bonus = complete_salaries_df.Option_Bonus.str.replace(',', '')
complete_salaries_df.Option_Bonus = complete_salaries_df.Option_Bonus.str.replace('-', '')

complete_salaries_df.Incentive = complete_salaries_df.Incentive.str.replace('$', '')
complete_salaries_df.Incentive = complete_salaries_df.Incentive.str.replace(',', '')
complete_salaries_df.Incentive = complete_salaries_df.Incentive.str.replace('-', '')

# %%
complete_salaries_df
# Out:
#               Player_Name                 Spotrac_ID  Year        Team  \
# 0             Eli Manning           eli-manning-4348  2004    nygiants
# 1             Eli Manning           eli-manning-4348  2005    nygiants
# 2             Eli Manning           eli-manning-4348  2006    nygiants
# 3             Eli Manning           eli-manning-4348  2007    nygiants
# 4             Eli Manning           eli-manning-4348  2008    nygiants
# 5             Eli Manning           eli-manning-4348  2009    nygiants
# 6             Eli Manning           eli-manning-4348  2010    nygiants
# 7             Eli Manning           eli-manning-4348  2011    nygiants
# 8             Eli Manning           eli-manning-4348  2012    nygiants
# 9             Eli Manning           eli-manning-4348  2013    nygiants
# 10            Eli Manning           eli-manning-4348  2014    nygiants
# 11            Eli Manning           eli-manning-4348  2015    nygiants
# ...

# %%
complete_salaries_df = complete_salaries_df.replace(to_replace={'arizona2': 'ARI', 'patriots': 'NWE', 'rams2': 'LAR', 'eagles1': 'PHI', 'vikings': 'MIN', 'bengals': 'CIN', '49erslogo': 'SFO', 'colts': 'IND', 'oakland': 'OAK', 'browns': 'CLE', 'nygiants': 'NYG', 'panthers': 'CAR', 'falcons': 'ATL', 'bucs': 'TAM', 'bears': 'CHI', 'dolphins': 'MIA', 'svg_': 'LAC', 'hawks3': 'SEA', 'dallas': 'DAL', 'ravens': 'BAL', 'lions': 'DET', 'broncos': 'DEN', 'buffalo': 'BUF',
 'neworleans': 'NOR', 'packers': 'GNB', 'washington': 'WAS', 'kansascity': 'KAN', 'tennessee': 'TEN', 'texans': 'HOU', 'chargers2': 'SDG', 'jets': 'NYJ', 'jaguars': 'JAX', 'rams3': 'STL', 'Pittsburgh-Steelers-logo-psd22874': 'PIT'})

complete_salaries_df
# Out:
#               Player_Name                 Spotrac_ID  Year Team    Salary  \
# 0             Eli Manning           eli-manning-4348  2004  NYG   1744000
# 1             Eli Manning           eli-manning-4348  2005  NYG    305000
# 2             Eli Manning           eli-manning-4348  2006  NYG   1641000
# 3             Eli Manning           eli-manning-4348  2007  NYG   6450000
# 4             Eli Manning           eli-manning-4348  2008  NYG   8450000
# 5             Eli Manning           eli-manning-4348  2009  NYG   7500000
# 6             Eli Manning           eli-manning-4348  2010  NYG   6500000
# 7             Eli Manning           eli-manning-4348  2011  NYG   8500000
# 8             Eli Manning           eli-manning-4348  2012  NYG   1750000
# 9             Eli Manning           eli-manning-4348  2013  NYG  13000000
# 10            Eli Manning           eli-manning-4348  2014  NYG  15150000
# 11            Eli Manning           eli-manning-4348  2015  NYG   5500000
# ...

# %%
names = complete_salaries_df['Player_Name'].tolist()
years = complete_salaries_df['Year'].tolist()
teams = complete_salaries_df['Team'].tolist()

names_under = [i.replace(' ', '_') for i in names]

my_id = []
if len(names) == len(names_under):
    for i in range(len(names_under)):
        my_id.append("{}_{}_{}".format(names_under[i], years[i], teams[i]))
    else:
        print(len(names), len(names_under))

# %%
complete_salaries_df.insert(0, 'my_ids', my_id)

complete_salaries_df
# Out:
#                             my_ids          Player_Name  \
# 0             Eli_Manning_2004_NYG          Eli Manning
# 1             Eli_Manning_2005_NYG          Eli Manning
# 2             Eli_Manning_2006_NYG          Eli Manning
# 3             Eli_Manning_2007_NYG          Eli Manning
# 4             Eli_Manning_2008_NYG          Eli Manning
# 5             Eli_Manning_2009_NYG          Eli Manning
# 6             Eli_Manning_2010_NYG          Eli Manning
# 7             Eli_Manning_2011_NYG          Eli Manning
# 8             Eli_Manning_2012_NYG          Eli Manning
# 9             Eli_Manning_2013_NYG          Eli Manning
# 10            Eli_Manning_2014_NYG          Eli Manning
# 11            Eli_Manning_2015_NYG          Eli Manning
# 12            Eli_Manning_2016_NYG          Eli Manning
# 13            Eli_Manning_2017_NYG          Eli Manning
# 14            Eli_Manning_2018_NYG          Eli Manning
# 15         Olivier_Vernon_2012_MIA       Olivier Vernon
# ...

# %%
basepath = "/Users/coltkess/Desktop/" #####
file_name = "fantasy_fb_since2000.csv"
pathtofile = os.path.join(basepath, file_name) 

fantasy_stats_df = pd.read_csv("/Users/coltkess/PycharmProjects/fantasy_fb_contract_year/fantasy_football_since2000.csv")

fantasy_stats_df.head()
# Out:
#    Season  Rk            Player Team Position   Age     G    GS  Pass_Cmp  \
# 0    2000 NaN    Marshall Faulk  STL       RB  27.0  14.0  14.0       0.0
# 1    2000 NaN    Edgerrin James  IND       RB  22.0  16.0  16.0       0.0
# 2    2000 NaN  Daunte Culpepper  MIN       QB  23.0  16.0  16.0     297.0
# 3    2000 NaN       Jeff Garcia  SFO       QB  30.0  16.0  16.0     355.0
# 4    2000 NaN      Eddie George  TEN       RB  27.0  16.0  16.0       0.0
#
#    Pass_Att         ...           Two_PT_Pass  Fantasy_Pts  PPR_Pts  \
# 0       0.0         ...                   NaN        381.0    460.0
# 1       0.0         ...                   NaN        340.0    398.0
# 2     474.0         ...                   2.0        350.0    339.0
# 3     561.0         ...                   1.0        343.0    336.0
# 4       0.0         ...                   NaN        292.0    337.0
#
#    DraftKings_Pts  FanDuel_Pts    VBD  PosRank  OvRank  \
# ...

# %%
names2 = fantasy_stats_df['Player'].tolist()
years2 = fantasy_stats_df['Season'].tolist()
teams2 = fantasy_stats_df['Team'].tolist()

names_under2 = [i.replace(' ', '_') for i in names2]

my_id2 = []
if len(names2) == len(names_under2):
    for i in range(len(names_under2)):
        my_id2.append("{}_{}_{}".format(names_under2[i], years2[i], teams2[i]))
    else:
        print(len(names2), len(names_under2))
# Out:
# 10650 10650

# %%
fantasy_stats_df.insert(0, 'my_ids', my_id2)

# %%
fantasy_stats_df.head(50)
# Out:
#                         my_ids  Season  Rk             Player Team Position  \
# 0      Marshall_Faulk_2000_STL    2000 NaN     Marshall Faulk  STL       RB
# 1      Edgerrin_James_2000_IND    2000 NaN     Edgerrin James  IND       RB
# 2    Daunte_Culpepper_2000_MIN    2000 NaN   Daunte Culpepper  MIN       QB
# 3         Jeff_Garcia_2000_SFO    2000 NaN        Jeff Garcia  SFO       QB
# 4        Eddie_George_2000_TEN    2000 NaN       Eddie George  TEN       RB
# 5          Randy_Moss_2000_MIN    2000 NaN         Randy Moss  MIN       WR
# 6       Tony_Gonzalez_2000_KAN    2000 NaN      Tony Gonzalez  KAN       TE
# 7       Terrell_Owens_2000_SFO    2000 NaN      Terrell Owens  SFO       WR
# 8     Marvin_Harrison_2000_IND    2000 NaN    Marvin Harrison  IND       WR
# 9           Rod_Smith_2000_DEN    2000 NaN          Rod Smith  DEN       WR
# 10      Mike_Anderson_2000_DEN    2000 NaN      Mike Anderson  DEN       RB
# ...

# %%
full_df = pd.merge(fantasy_stats_df, complete_salaries_df, on='my_ids', how='inner')

full_df
# Out:
#                            my_ids  Season  Rk              Player Team_x  \
# 0              Tom_Brady_2000_NWE    2000 NaN           Tom Brady    NWE
# 1              Tom_Brady_2001_NWE    2001 NaN           Tom Brady    NWE
# 2             Drew_Brees_2001_SDG    2001 NaN          Drew Brees    SDG
# 3              Tom_Brady_2002_NWE    2002 NaN           Tom Brady    NWE
# 4             Drew_Brees_2002_SDG    2002 NaN          Drew Brees    SDG
# 5            Josh_McCown_2002_ARI    2002 NaN         Josh McCown    ARI
# 6              Tom_Brady_2003_NWE    2003 NaN           Tom Brady    NWE
# 7             Drew_Brees_2003_SDG    2003 NaN          Drew Brees    SDG
# 8            Josh_McCown_2003_ARI    2003 NaN         Josh McCown    ARI
# 9          Antonio_Gates_2003_SDG    2003 NaN       Antonio Gates    SDG
# 10         Antonio_Gates_2004_SDG    2004 NaN       Antonio Gates    SDG
# 11            Drew_Brees_2004_SDG    2004 NaN          Drew Brees    SDG
# ...

# %%
full_df = full_df.drop(columns=['Season', 'Player_Name','Team_x','Rk'])

# %%
full_df = full_df.apply(pd.to_numeric, errors="ignore")

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1636 entries, 0 to 1635
# Data columns (total 42 columns):
# my_ids               1636 non-null object
# Player               1636 non-null object
# Position             1541 non-null object
# Age                  1636 non-null float64
# G                    1632 non-null float64
# GS                   1619 non-null float64
# Pass_Cmp             1636 non-null float64
# Pass_Att             1636 non-null float64
# Pass_Yds             1636 non-null float64
# Pass_TD              1636 non-null float64
# Pass_INT             1636 non-null float64
# Rush_Att             1636 non-null float64
# Rush_Yds             1636 non-null float64
# Rush_YpA             945 non-null float64
# Rush_TD              1636 non-null float64
# Rec_Tgt              1601 non-null float64
# Rec                  1636 non-null float64
# Rec_Yds              1636 non-null float64
# Rec_YpR              1218 non-null float64
# ...

# %%
num_cols = full_df.columns[full_df.dtypes != object]

full_df.loc[:, num_cols] = full_df.loc[:, num_cols].fillna(0)

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1636 entries, 0 to 1635
# Data columns (total 42 columns):
# my_ids               1636 non-null object
# Player               1636 non-null object
# Position             1541 non-null object
# Age                  1636 non-null float64
# G                    1636 non-null float64
# GS                   1636 non-null float64
# Pass_Cmp             1636 non-null float64
# Pass_Att             1636 non-null float64
# Pass_Yds             1636 non-null float64
# Pass_TD              1636 non-null float64
# Pass_INT             1636 non-null float64
# Rush_Att             1636 non-null float64
# Rush_Yds             1636 non-null float64
# Rush_YpA             1636 non-null float64
# Rush_TD              1636 non-null float64
# Rec_Tgt              1636 non-null float64
# Rec                  1636 non-null float64
# Rec_Yds              1636 non-null float64
# Rec_YpR              1636 non-null float64
# ...

# %%
# Import necessary packages, set some plotting styles
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import rcParams

# set the font scaling and the plot sizes
sns.set(font_scale=1.65)
rcParams["figure.figsize"] = 12, 9

# %%
lm = sns.lmplot(x="Fantasy_Pts", y="Total_Cash", data=full_df.loc[(full_df['Position'].isin(["QB", "RB", "WR", "TE"]))], 
                fit_reg=True, col="Position", col_wrap=4, size=4, line_kws={"color": "black"}, 
                scatter_kws={"color": sns.color_palette()[5], "alpha": 0.4})
plt.subplots_adjust(top=3)

plt.xlim(0, 400)
plt.ylim(0, 50000000)
plt.show()
